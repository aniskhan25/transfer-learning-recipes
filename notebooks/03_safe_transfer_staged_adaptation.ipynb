# %% [markdown]
# # 03 Safe transfer with staged adaptation
#
# This notebook is a minimal educational implementation.
# It is designed for conceptual understanding, not exact reproduction of a benchmark.
#
# We compare scratch training, feature extraction, gradual unfreezing, and naive fine-tuning under one shared setup.

# %% [markdown]
# ## Concept
#
# A transferred representation can help the target task, but only if we adapt it carefully.
#
# The central question here is: how do we improve target accuracy without destroying the useful structure learned on the source task?

# %% [markdown]
# ## Why this method exists
#
# Naive fine-tuning updates all layers immediately.
# That can work, but in low-label settings it often moves the representation too fast and erases source knowledge.
#
# Safe transfer methods exist to slow that process down:
# - feature extraction keeps the backbone fixed
# - gradual unfreezing adapts the model in stages

# %% [markdown]
# ## Algorithm intuition
#
# Gradual unfreezing follows a staged loop:
# 1. start from a pretrained source model
# 2. train only the target head first
# 3. unfreeze deeper layers later
# 4. monitor target accuracy, source retention, and feature drift
#
# The point is not only to get a high final score.
# The point is to adapt without destabilizing the representation.

# %% [markdown]
# ## Before You Run
#
# `FAST_DEV_RUN=True` uses the quick teaching setup: more target labels, shorter runs, and smoother curves.
# Set `FAST_DEV_RUN=False` for the harder few-label setting with longer runs and sharper method differences.
#
# What to watch:
# - whether gradual unfreezing matches or beats naive target accuracy
# - whether source retention stays higher for the safer methods
# - whether feature drift stays lower when adaptation is staged

# %% [markdown]
# ## Step 1: Imports
#
# Keep the workflow explicit and visible.

# %%
from pathlib import Path
import sys
import random
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'src').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from data.cifar10_transfer import get_cifar10_transfer
from models.transfer_resnet import TransferResNet18
from methods.transfer_learning import pretrain_source, build_transferred_model, run_target_adaptation

# %% [markdown]
# ## Step 2: Configuration
#
# Keep the setup visible in one place.

# %%
FAST_DEV_RUN = True

config = {
    'seed': 42,
    'data_dir': './data',
    'source_classes': [2, 3, 4, 5, 6, 7],
    'target_classes': [2, 4, 6],
    'source_train_per_class': 400 if FAST_DEV_RUN else 1000,
    'source_test_per_class': 120 if FAST_DEV_RUN else 300,
    'target_train_per_class': 40 if FAST_DEV_RUN else 25,
    'target_test_per_class': 180 if FAST_DEV_RUN else 300,
    'probe_per_class': 60 if FAST_DEV_RUN else 120,
    'batch_size': 128,
    'num_workers': 2,
    'source_epochs': 4 if FAST_DEV_RUN else 6,
    'target_epochs': 8 if FAST_DEV_RUN else 14,
    'lr_source': 0.03,
    'lr_target': 0.015 if FAST_DEV_RUN else 0.02,
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'methods': ['scratch', 'feature_extraction', 'gradual_unfreeze', 'naive_finetune'],
    'gradual_schedule': {
        2: ['backbone.layer4'],
        4: ['backbone.layer3', 'backbone.layer2'],
        6: ['backbone.layer1', 'backbone.bn1', 'backbone.conv1'],
    } if FAST_DEV_RUN else {
        3: ['backbone.layer4'],
        6: ['backbone.layer3', 'backbone.layer2'],
        9: ['backbone.layer1', 'backbone.bn1', 'backbone.conv1'],
    },
}

print(config)

seed = config['seed']
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', DEVICE)

FIGS = ROOT / 'outputs' / 'figures'
FIGS.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Step 3: Build the shared data split
#
# All methods use the same source task, target task, seed, and model family.

# %%
loaders = get_cifar10_transfer(
    data_dir=config['data_dir'],
    source_classes=config['source_classes'],
    target_classes=config['target_classes'],
    source_train_per_class=config['source_train_per_class'],
    source_test_per_class=config['source_test_per_class'],
    target_train_per_class=config['target_train_per_class'],
    target_test_per_class=config['target_test_per_class'],
    probe_per_class=config['probe_per_class'],
    batch_size=config['batch_size'],
    num_workers=config['num_workers'],
    seed=config['seed'],
)

print('source classes:', loaders.source_num_classes)
print('target classes:', loaders.target_num_classes)

# %% [markdown]
# ## Step 4: Pretrain the source model
#
# This creates the representation that transfer methods will reuse.

# %%
source_model = TransferResNet18(num_classes=loaders.source_num_classes)
source_result = pretrain_source(
    model=source_model,
    train_loader=loaders.source_train,
    test_loader=loaders.source_test,
    device=DEVICE,
    epochs=config['source_epochs'],
    lr=config['lr_source'],
    weight_decay=config['weight_decay'],
    momentum=config['momentum'],
    use_progress=True,
)

source_history = pd.DataFrame(source_result.history)
source_history

# %% [markdown]
# ## Step 5: Train the baseline and transfer methods
#
# Scratch is the baseline.
# The transfer methods all reuse the pretrained source model.

# %%
frames = {}

for method in config['methods']:
    if method == 'scratch':
        model = TransferResNet18(num_classes=loaders.target_num_classes)
        source_head = None
        source_test = None
    else:
        model, source_head = build_transferred_model(source_model, loaders.target_num_classes)
        source_test = loaders.source_test

    result = run_target_adaptation(
        model=model,
        target_train=loaders.target_train,
        target_test=loaders.target_test,
        target_probe=loaders.target_probe,
        source_test=source_test,
        source_head=source_head,
        device=DEVICE,
        strategy=method,
        epochs=config['target_epochs'],
        lr=config['lr_target'],
        weight_decay=config['weight_decay'],
        momentum=config['momentum'],
        gradual_schedule=config['gradual_schedule'],
        use_progress=True,
    )
    frames[method] = pd.DataFrame(result.history)

frames['gradual_unfreeze'].head()

# %% [markdown]
# ## Step 6: Final summary table
#
# How to read:
# - higher `best_target_acc` is better
# - positive `acc_gain_vs_scratch` means the method helped compared with the baseline
# - higher `final_retention` is better because more source knowledge survived
# - lower `final_feature_drift` is better if target accuracy is similar

# %%
scratch_final = float(frames['scratch']['target_test_acc'].iloc[-1])
summary = pd.DataFrame([
    {
        'method': method,
        'best_target_acc': float(df['target_test_acc'].max()),
        'final_target_acc': float(df['target_test_acc'].iloc[-1]),
        'acc_gain_vs_scratch': float(df['target_test_acc'].iloc[-1] - scratch_final),
        'final_retention': float(df['source_retention_acc'].iloc[-1]) if not df['source_retention_acc'].isna().all() else float('nan'),
        'final_feature_drift': float(df['feature_drift'].iloc[-1]),
        'final_grad_norm': float(df['grad_norm'].iloc[-1]),
    }
    for method, df in frames.items()
]).sort_values('best_target_acc', ascending=False)
summary

# %% [markdown]
# ## Step 7: Diagnostics
#
# Plot the dynamics, not just the endpoints.
#
# How to read:
# - higher target accuracy is better
# - higher source retention is better
# - lower feature drift is better
# - if gradual unfreezing and naive fine-tuning finish close in accuracy, retention and drift should decide the comparison

# %%
fig, ax = plt.subplots(figsize=(6.6, 3.7))
for method, df in frames.items():
    ax.plot(df['epoch'], df['target_test_acc'], marker='o', label=method)
ax.set_title('Validation accuracy comparison')
ax.set_xlabel('epoch')
ax.set_ylabel('target_test_acc')
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.savefig(FIGS / '03_target_acc_comparison.png', dpi=150, bbox_inches='tight')

fig, ax = plt.subplots(figsize=(6.6, 3.7))
for method in ['feature_extraction', 'gradual_unfreeze', 'naive_finetune']:
    df = frames[method]
    ax.plot(df['epoch'], df['source_retention_acc'], marker='o', label=method)
ax.set_title('Source retention comparison')
ax.set_xlabel('epoch')
ax.set_ylabel('source_retention_acc')
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.savefig(FIGS / '03_source_retention_comparison.png', dpi=150, bbox_inches='tight')

fig, ax = plt.subplots(figsize=(6.6, 3.7))
for method in ['feature_extraction', 'gradual_unfreeze', 'naive_finetune']:
    df = frames[method]
    ax.plot(df['epoch'], df['feature_drift'], marker='o', label=method)
ax.set_title('Feature drift comparison')
ax.set_xlabel('epoch')
ax.set_ylabel('feature_drift')
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.savefig(FIGS / '03_feature_drift_comparison.png', dpi=150, bbox_inches='tight')

# %%
safe = frames['gradual_unfreeze']
naive = frames['naive_finetune']
comparison = safe[['epoch']].copy()
comparison['delta_target_acc_safe_minus_naive'] = safe['target_test_acc'] - naive['target_test_acc']
comparison['delta_retention_safe_minus_naive'] = safe['source_retention_acc'] - naive['source_retention_acc']
comparison

# %% [markdown]
# ## Expected observations and interpretation
#
# What you should usually see:
# - scratch is the clean baseline, but not usually the best transfer choice
# - gradual unfreezing should retain more source skill than naive fine-tuning
# - feature extraction may be the safest method, but not always the strongest final method
#
# How to interpret close finishes:
# - if naive fine-tuning and gradual unfreezing end close in target accuracy, that does not make them equivalent
# - if gradual unfreezing keeps noticeably higher retention or lower drift, it is the safer update rule
# - if all methods are close, the run may be too easy or too short to separate them clearly

# %% [markdown]
# ## Key takeaways
#
# - Safe transfer methods protect useful source structure while adapting to the target task.
# - A fair comparison keeps the data split, seed, and model family fixed.
# - The right decision depends on both target accuracy and stability diagnostics.

# %% [markdown]
# ## Failure modes
#
# Common ways this notebook can mislead:
# - the run is too short, so gradual unfreezing does not have time to separate from naive fine-tuning
# - the target task is too easy, so all methods look similar
# - the learner looks only at the final target score and ignores retention or drift
# - a method with the highest final accuracy may still be the wrong production choice if it destroys the source representation
