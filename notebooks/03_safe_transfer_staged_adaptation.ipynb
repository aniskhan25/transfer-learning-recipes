# %% [markdown]
# # 03 Safe transfer with staged adaptation
#
# This notebook is a minimal educational implementation.
# It is designed for conceptual understanding, not exact reproduction of a benchmark.
#
# We compare scratch training, feature extraction, gradual unfreezing, and naive fine-tuning across multiple seeds so the safety story does not depend on one noisy run.

# %% [markdown]
# ## Concept
#
# A transferred representation can help the target task, but only if we adapt it carefully.
#
# The central question is:
# how do we improve target accuracy without destroying the useful structure learned on the source task?

# %% [markdown]
# ## Why this method exists
#
# Naive fine-tuning updates all layers immediately.
# That can work, but in low-label settings it often moves the representation too fast and erases source knowledge.
#
# Safe transfer methods slow that process down:
# - feature extraction keeps the backbone fixed
# - gradual unfreezing adapts the model in stages

# %% [markdown]
# ## Algorithm intuition
#
# Gradual unfreezing follows a staged loop:
# 1. start from a pretrained source model
# 2. train the target head first
# 3. unfreeze deeper layers later
# 4. monitor target accuracy, source retention, and feature drift
#
# The point is not only to get a high final score.
# The point is to adapt without destabilizing the representation.

# %% [markdown]
# ## Before You Run
#
# `FAST_DEV_RUN=True` uses a smoother teaching setup with one stable label budget and several seeds.
# Set `FAST_DEV_RUN=False` for the harder few-label setting.
#
# What to watch:
# - whether gradual unfreezing matches or beats naive fine-tuning on average
# - whether source retention stays higher for the safer methods
# - whether feature drift stays lower when adaptation is staged
# - whether the ranking stays stable across seeds

# %% [markdown]
# ## Step 1: Imports
#
# Keep the workflow explicit and visible.

# %%
from pathlib import Path
import sys
import random
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'src').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from data.cifar10_transfer import get_cifar10_transfer
from models.transfer_resnet import TransferResNet18
from methods.transfer_learning import pretrain_source, build_transferred_model, run_target_adaptation

# %% [markdown]
# ## Step 2: Configuration
#
# Keep the setup visible in one place.

# %%
FAST_DEV_RUN = True

config = {
    'data_dir': './data',
    'seeds': [13, 42, 77],
    'source_classes': [2, 3, 4, 5, 6, 7],
    'target_classes': [2, 4, 6],
    'source_train_per_class': 400 if FAST_DEV_RUN else 1000,
    'source_test_per_class': 120 if FAST_DEV_RUN else 300,
    'target_train_per_class': 80 if FAST_DEV_RUN else 50,
    'target_test_per_class': 300,
    'probe_per_class': 120,
    'batch_size': 128,
    'num_workers': 2,
    'source_epochs': 4 if FAST_DEV_RUN else 6,
    'target_epochs': 10 if FAST_DEV_RUN else 16,
    'lr_source': 0.03,
    'lr_target': 0.002 if FAST_DEV_RUN else 0.003,
    'source_optimizer': 'sgd',
    'target_optimizer': 'adamw',
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'methods': ['scratch', 'feature_extraction', 'gradual_unfreeze', 'naive_finetune'],
    'gradual_schedule': {
        2: ['backbone.layer4'],
        4: ['backbone.layer3', 'backbone.layer2'],
        6: ['backbone.layer1', 'backbone.bn1', 'backbone.conv1'],
    } if FAST_DEV_RUN else {
        3: ['backbone.layer4'],
        6: ['backbone.layer3', 'backbone.layer2'],
        9: ['backbone.layer1', 'backbone.bn1', 'backbone.conv1'],
    },
}

print(config)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', DEVICE)

FIGS = ROOT / 'outputs' / 'figures'
FIGS.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Step 3: Define one shared transfer runner
#
# Each seed sees the same tasks and methods.
# Only the random seed changes.

# %%
def run_safe_transfer(seed):
    print(f'Running seed={seed}')
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    loaders = get_cifar10_transfer(
        data_dir=config['data_dir'],
        source_classes=config['source_classes'],
        target_classes=config['target_classes'],
        source_train_per_class=config['source_train_per_class'],
        source_test_per_class=config['source_test_per_class'],
        target_train_per_class=config['target_train_per_class'],
        target_test_per_class=config['target_test_per_class'],
        probe_per_class=config['probe_per_class'],
        batch_size=config['batch_size'],
        num_workers=config['num_workers'],
        seed=seed,
    )

    source_model = TransferResNet18(num_classes=loaders.source_num_classes)
    source_result = pretrain_source(
        model=source_model,
        train_loader=loaders.source_train,
        test_loader=loaders.source_test,
        device=DEVICE,
        epochs=config['source_epochs'],
        lr=config['lr_source'],
        weight_decay=config['weight_decay'],
        momentum=config['momentum'],
        optimizer_name=config['source_optimizer'],
        use_progress=True,
    )

    frames = {}
    for method in config['methods']:
        if method == 'scratch':
            model = TransferResNet18(num_classes=loaders.target_num_classes)
            source_head = None
            source_test = None
        else:
            model, source_head = build_transferred_model(source_model, loaders.target_num_classes)
            source_test = loaders.source_test

        result = run_target_adaptation(
            model=model,
            target_train=loaders.target_train,
            target_test=loaders.target_test,
            target_probe=loaders.target_probe,
            source_test=source_test,
            source_head=source_head,
            device=DEVICE,
            strategy=method,
            epochs=config['target_epochs'],
            lr=config['lr_target'],
            weight_decay=config['weight_decay'],
            momentum=config['momentum'],
            optimizer_name=config['target_optimizer'],
            gradual_schedule=config['gradual_schedule'],
            use_progress=True,
        )
        frames[method] = pd.DataFrame(result.history)

    return {
        'loaders': loaders,
        'source_history': pd.DataFrame(source_result.history),
        'frames': frames,
    }

# %% [markdown]
# ## Step 4: Run the comparison across seeds
#
# This makes the safety story more reliable.

# %%
runs = {seed: run_safe_transfer(seed) for seed in config['seeds']}
representative_seed = config['seeds'][0]
sorted(runs)

# %% [markdown]
# ## Step 5: Final summary table
#
# How to read:
# - higher `mean_best_target_acc` is better
# - positive `mean_gain_vs_scratch` means the method helped on average
# - higher `mean_final_retention` is better because more source knowledge survived
# - lower `mean_final_feature_drift` is better if target accuracy is similar

# %%
rows = []
for seed, run in runs.items():
    scratch_final = float(run['frames']['scratch']['target_test_acc'].iloc[-1])
    for method, df in run['frames'].items():
        rows.append(
            {
                'seed': seed,
                'method': method,
                'best_target_acc': float(df['target_test_acc'].max()),
                'final_target_acc': float(df['target_test_acc'].iloc[-1]),
                'gain_vs_scratch': float(df['target_test_acc'].iloc[-1] - scratch_final),
                'final_retention': float(df['source_retention_acc'].iloc[-1]) if not df['source_retention_acc'].isna().all() else float('nan'),
                'final_feature_drift': float(df['feature_drift'].iloc[-1]),
                'final_grad_norm': float(df['grad_norm'].iloc[-1]),
            }
        )

summary = pd.DataFrame(rows)
dashboard = summary.groupby('method').agg(
    mean_best_target_acc=('best_target_acc', 'mean'),
    std_best_target_acc=('best_target_acc', 'std'),
    mean_final_target_acc=('final_target_acc', 'mean'),
    mean_gain_vs_scratch=('gain_vs_scratch', 'mean'),
    mean_final_retention=('final_retention', 'mean'),
    mean_final_feature_drift=('final_feature_drift', 'mean'),
    mean_final_grad_norm=('final_grad_norm', 'mean'),
).reset_index().sort_values('mean_best_target_acc', ascending=False)

dashboard

# %% [markdown]
# ## Step 6: Diagnostics
#
# Use one representative seed for curve reading, then use aggregated plots for the decision.
#
# How to read:
# - Plot A asks who learns fastest on one representative seed
# - Plot B asks whether safer methods keep more source knowledge
# - Plot C asks how accuracy and drift trade off across seeds
# - Plot D asks whether gradual unfreezing beats naive fine-tuning on average

# %%
rep_frames = runs[representative_seed]['frames']

epochs = rep_frames['scratch']['epoch'].to_numpy()
fig, ax = plt.subplots(figsize=(6.6, 3.7))
for method in config['methods']:
    curves = np.stack([runs[seed]['frames'][method]['target_test_acc'].to_numpy() for seed in config['seeds']])
    mean_curve = curves.mean(axis=0)
    std_curve = curves.std(axis=0)
    ax.plot(epochs, mean_curve, marker='o', label=method)
    ax.fill_between(epochs, mean_curve - std_curve, mean_curve + std_curve, alpha=0.12)
ax.set_title('Validation accuracy comparison across seeds')
ax.set_xlabel('epoch')
ax.set_ylabel('mean target_test_acc')
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.savefig(FIGS / '03_representative_target_acc.png', dpi=150, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6.6, 3.7))
for method in ['feature_extraction', 'gradual_unfreeze', 'naive_finetune']:
    df = rep_frames[method]
    ax.plot(df['epoch'], df['source_retention_acc'], marker='o', label=method)
ax.set_title(f'Source retention comparison (seed={representative_seed})')
ax.set_xlabel('epoch')
ax.set_ylabel('source_retention_acc')
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.savefig(FIGS / '03_representative_retention.png', dpi=150, bbox_inches='tight')

# %%
transfer_only = dashboard[dashboard['method'] != 'scratch']
fig, axes = plt.subplots(1, 2, figsize=(10.2, 3.7))

axes[0].scatter(transfer_only['mean_final_feature_drift'], transfer_only['mean_best_target_acc'], s=90)
for _, row in transfer_only.iterrows():
    axes[0].text(row['mean_final_feature_drift'] + 0.004, row['mean_best_target_acc'] + 0.002, row['method'], fontsize=9)
axes[0].set_title('Accuracy-drift tradeoff across seeds')
axes[0].set_xlabel('mean_final_feature_drift')
axes[0].set_ylabel('mean_best_target_acc')
axes[0].grid(alpha=0.25)

safe = dashboard[dashboard['method'] == 'gradual_unfreeze'].iloc[0]
naive = dashboard[dashboard['method'] == 'naive_finetune'].iloc[0]
delta = pd.DataFrame([
    {'metric': 'mean_best_target_acc', 'safe_minus_naive': float(safe['mean_best_target_acc'] - naive['mean_best_target_acc'])},
    {'metric': 'mean_final_retention', 'safe_minus_naive': float(safe['mean_final_retention'] - naive['mean_final_retention'])},
    {'metric': 'mean_final_feature_drift', 'safe_minus_naive': float(safe['mean_final_feature_drift'] - naive['mean_final_feature_drift'])},
])
axes[1].bar(delta['metric'], delta['safe_minus_naive'])
axes[1].axhline(0.0, color='black', linewidth=1, linestyle='--')
axes[1].set_title('Safe minus naive summary')
axes[1].tick_params(axis='x', rotation=20)
axes[1].grid(axis='y', alpha=0.25)

plt.tight_layout()
plt.savefig(FIGS / '03_safe_vs_naive_dashboard.png', dpi=150, bbox_inches='tight')

delta

# %%
source_history = runs[representative_seed]['source_history']
fig, ax = plt.subplots(figsize=(5.8, 3.3))
ax.plot(source_history['epoch'], source_history['source_test_acc'], marker='o')
ax.set_title(f'Source pretraining accuracy (seed={representative_seed})')
ax.set_xlabel('epoch')
ax.set_ylabel('source_test_acc')
ax.grid(alpha=0.25)
fig.savefig(FIGS / '03_source_pretrain_acc.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ## Expected observations and interpretation
#
# What you should usually see:
# - scratch is the clean baseline, but not usually the best transfer choice
# - gradual unfreezing should retain more source skill than naive fine-tuning on average
# - feature extraction may be the safest method, but not always the strongest final method
# - safer methods should look convincing across seeds, not only on one run
#
# How to interpret close finishes:
# - if naive fine-tuning and gradual unfreezing end close in target accuracy, that does not make them equivalent
# - if gradual unfreezing keeps noticeably higher retention or lower drift, it is the safer update rule
# - if all methods are close, the run may be too easy or too short to separate them clearly

# %% [markdown]
# ## Key takeaways
#
# - Safe transfer methods protect useful source structure while adapting to the target task.
# - A fair comparison keeps the tasks, model family, and label budget fixed.
# - The right decision depends on both target accuracy and stability diagnostics.
# - A good teaching notebook should not hinge on one fragile seed.

# %% [markdown]
# ## Failure modes
#
# - If the run is too short, gradual unfreezing may not have time to separate from naive fine-tuning.
# - If the target task is too easy, all methods can look similar.
# - If you look only at final accuracy, you can miss retention collapse.
# - A method with the highest final score may still be the wrong choice if it destroys the source representation.
